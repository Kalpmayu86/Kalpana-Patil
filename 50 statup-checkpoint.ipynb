# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from statsmodels.graphics.regressionplots import influence_plot
import statsmodels.formula.api as smf
import numpy as np

# %%
df =pd.read_csv("C:\\Users\\kalpana\\Downloads\\50_Startups.csv")

# %%
df
# Out:
#     R&D Spend  Administration  Marketing Spend       State     Profit
# 0   165349.20       136897.80        471784.10    New York  192261.83
# 1   162597.70       151377.59        443898.53  California  191792.06
# 2   153441.51       101145.55        407934.54     Florida  191050.39
# 3   144372.41       118671.85        383199.62    New York  182901.99
# 4   142107.34        91391.77        366168.42     Florida  166187.94
# 5   131876.90        99814.71        362861.36    New York  156991.12
# 6   134615.46       147198.87        127716.82  California  156122.51
# 7   130298.13       145530.06        323876.68     Florida  155752.60
# 8   120542.52       148718.95        311613.29    New York  152211.77
# 9   123334.88       108679.17        304981.62  California  149759.96
# 10  101913.08       110594.11        229160.95     Florida  146121.95
# 11  100671.96        91790.61        249744.55  California  144259.40
# ...

# %%
df.shape
# Out:
# (50, 5)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 5 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   R&D Spend        48 non-null     float64
#  1   Administration   50 non-null     float64
#  2   Marketing Spend  47 non-null     float64
#  3   State            50 non-null     object
#  4   Profit           50 non-null     float64
# dtypes: float64(4), object(1)
# memory usage: 2.1+ KB

# %%
df
# Out:
#     R&D Spend  Administration  Marketing Spend       State     Profit
# 0   165349.20       136897.80        471784.10    New York  192261.83
# 1   162597.70       151377.59        443898.53  California  191792.06
# 2   153441.51       101145.55        407934.54     Florida  191050.39
# 3   144372.41       118671.85        383199.62    New York  182901.99
# 4   142107.34        91391.77        366168.42     Florida  166187.94
# 5   131876.90        99814.71        362861.36    New York  156991.12
# 6   134615.46       147198.87        127716.82  California  156122.51
# 7   130298.13       145530.06        323876.68     Florida  155752.60
# 8   120542.52       148718.95        311613.29    New York  152211.77
# 9   123334.88       108679.17        304981.62  California  149759.96
# 10  101913.08       110594.11        229160.95     Florida  146121.95
# 11  100671.96        91790.61        249744.55  California  144259.40
# ...

# %%
df.describe()
# Out:
#            R&D Spend  Administration  Marketing Spend         Profit
# count      48.000000       50.000000        47.000000      50.000000
# mean    76793.349583   121344.639600    224494.784894  112012.639200
# std     44224.086236    28017.802755    113316.503936   40306.180338
# min       542.050000    51283.140000      1903.930000   14681.400000
# 25%     45528.002500   103730.875000    139268.715000   90138.902500
# 50%     74661.715000   122699.795000    229160.950000  107978.190000
# 75%    105065.712500   144842.180000    301528.275000  139765.977500
# max    165349.200000   182645.560000    471784.100000  192261.830000

# %%
df.corr()
# Out:
#                  R&D Spend  Administration  Marketing Spend    Profit
# R&D Spend         1.000000        0.269749         0.708253  0.977401
# Administration    0.269749        1.000000        -0.076943  0.200717
# Marketing Spend   0.708253       -0.076943         1.000000  0.747434
# Profit            0.977401        0.200717         0.747434  1.000000

# %%
#Format the plot background and scatter plots for all the variables
sns.set_style(style='darkgrid')
sns.pairplot(df)

# %%
subscriber=df.groupby("State")["Profit"].sum().nlargest(15)
plt.figure(figsize=(12,8),dpi=80)
subscriber.plot.bar(color="#dd0088")
plt.title("Profit",fontsize=16)
plt.show()

# %%
sns.boxplot(df.Profit)
# Out:
# C:\Users\kalpana\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Profit'>

# %% [markdown]
# # outlier treatment

# %%
print(np.where(df['Profit']<40000))
# Out:
# (array([48, 49], dtype=int64),)

# %%
sns.boxplot(df.Profit)
# Out:
# C:\Users\kalpana\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Profit'>

# %% [markdown]
# # missing value

# %%
df.isnull().sum()
# Out:
# R&D Spend          2
# Administration     0
# Marketing Spend    3
# State              0
# Profit             0
# dtype: int64

# %% [markdown]
# # position of the missing value

# %%
import seaborn as sns
cols = df.columns 
colours = ['#000099', '#ffff00'] # specify the colours - yellow is missing. blue is not missing.
sns.heatmap(df[cols].isnull(),
            cmap=sns.color_palette(colours))
# Out:
# <AxesSubplot:>

# %%
#Mean Imputation
mean = df['R&D Spend'].mean()
print(mean)
# Out:
# 76793.34958333333

# %%
mean1 = df['Marketing Spend'].mean()
print(mean1)
# Out:
# 224494.78489361706

# %%
df
# Out:
#     R&D Spend  Administration  Marketing Spend       State     Profit
# 0   165349.20       136897.80        471784.10    New York  192261.83
# 1   162597.70       151377.59        443898.53  California  191792.06
# 2   153441.51       101145.55        407934.54     Florida  191050.39
# 3   144372.41       118671.85        383199.62    New York  182901.99
# 4   142107.34        91391.77        366168.42     Florida  166187.94
# 5   131876.90        99814.71        362861.36    New York  156991.12
# 6   134615.46       147198.87        127716.82  California  156122.51
# 7   130298.13       145530.06        323876.68     Florida  155752.60
# 8   120542.52       148718.95        311613.29    New York  152211.77
# 9   123334.88       108679.17        304981.62  California  149759.96
# 10  101913.08       110594.11        229160.95     Florida  146121.95
# 11  100671.96        91790.61        249744.55  California  144259.40
# ...

# %%
df['R&D Spend'] = df['R&D Spend'].fillna(mean)

# %%
df['Marketing Spend'] = df['Marketing Spend'].fillna(mean)

# %%
df.isnull().sum()
# Out:
# R&D Spend          0
# Administration     0
# Marketing Spend    0
# State              0
# Profit             0
# dtype: int64

# %%
df
# Out:
#         R&D Spend  Administration  Marketing Spend       State     Profit
# 0   165349.200000       136897.80    471784.100000    New York  192261.83
# 1   162597.700000       151377.59    443898.530000  California  191792.06
# 2   153441.510000       101145.55    407934.540000     Florida  191050.39
# 3   144372.410000       118671.85    383199.620000    New York  182901.99
# 4   142107.340000        91391.77    366168.420000     Florida  166187.94
# 5   131876.900000        99814.71    362861.360000    New York  156991.12
# 6   134615.460000       147198.87    127716.820000  California  156122.51
# 7   130298.130000       145530.06    323876.680000     Florida  155752.60
# 8   120542.520000       148718.95    311613.290000    New York  152211.77
# 9   123334.880000       108679.17    304981.620000  California  149759.96
# 10  101913.080000       110594.11    229160.950000     Florida  146121.95
# 11  100671.960000        91790.61    249744.550000  California  144259.40
# ...

# %%
df
# Out:
#         R&D Spend  Administration  Marketing Spend       State     Profit
# 0   165349.200000       136897.80    471784.100000    New York  192261.83
# 1   162597.700000       151377.59    443898.530000  California  191792.06
# 2   153441.510000       101145.55    407934.540000     Florida  191050.39
# 3   144372.410000       118671.85    383199.620000    New York  182901.99
# 4   142107.340000        91391.77    366168.420000     Florida  166187.94
# 5   131876.900000        99814.71    362861.360000    New York  156991.12
# 6   134615.460000       147198.87    127716.820000  California  156122.51
# 7   130298.130000       145530.06    323876.680000     Florida  155752.60
# 8   120542.520000       148718.95    311613.290000    New York  152211.77
# 9   123334.880000       108679.17    304981.620000  California  149759.96
# 10  101913.080000       110594.11    229160.950000     Florida  146121.95
# 11  100671.960000        91790.61    249744.550000  California  144259.40
# ...

# %%
df.drop(['State'],axis=1,inplace=True)

# %%
from sklearn.preprocessing import MinMaxScaler
norm =MinMaxScaler()
df_norm = norm.fit_transform(df)

# %%
df_norm
# Out:
# array([[1.        , 0.65174393, 1.        , 1.        ],
#        [0.98330473, 0.76197173, 0.94065387, 0.99735461],
#        [0.92774773, 0.37957895, 0.86411523, 0.99317808],
#        [0.87271918, 0.51299839, 0.81147432, 0.94729239],
#        [0.85897541, 0.30532804, 0.77522848, 0.85317138],
#        [0.7969002 , 0.3694479 , 0.76819039, 0.80138177],
#        [0.81351695, 0.73016111, 0.26775527, 0.79649041],
#        [0.7873207 , 0.71745725, 0.68522311, 0.79440736],
#        [0.7281266 , 0.74173276, 0.65912413, 0.77446805],
#        [0.7450698 , 0.43692884, 0.6450106 , 0.7606613 ],
#        [0.61508879, 0.45150637, 0.48364888, 0.74017475],
#        [0.60755805, 0.30836422, 0.52745495, 0.72968626],
#        [0.56624788, 0.57883556, 0.52765689, 0.71462897],
#        [0.55489304, 0.64106561, 0.53367011, 0.67364377],
#        [0.72449035, 0.8013272 , 0.54185941, 0.66404417],
#        [0.69160567, 0.54302973, 0.55306079, 0.64892083],
# ...

# %%
df2 = pd.DataFrame(df_norm)

# %%
df2.columns=['RD_S','Admin','Mark_S','Profit']

# %%
df2.head()
# Out:
#        RD_S     Admin    Mark_S    Profit
# 0  1.000000  0.651744  1.000000  1.000000
# 1  0.983305  0.761972  0.940654  0.997355
# 2  0.927748  0.379579  0.864115  0.993178
# 3  0.872719  0.512998  0.811474  0.947292
# 4  0.858975  0.305328  0.775228  0.853171

# %%
import statsmodels.formula.api as smf
from statsmodels.graphics.regressionplots import influence_plot

# %%
model1 = smf.ols('Profit ~ RD_S+Admin+Mark_S',data=df2).fit()

# %%
model1.params
# Out:
# Intercept    0.136587
# RD_S         0.582564
# Admin        0.034707
# Mark_S       0.271435
# dtype: float64

# %%
np.round(model1.tvalues, 4),np.round(model1.pvalues, 4)
# Out:
# (Intercept    2.8701
#  RD_S         7.2828
#  Admin        0.4765
#  Mark_S       3.2881
#  dtype: float64,
#  Intercept    0.0062
#  RD_S         0.0000
#  Admin        0.6360
#  Mark_S       0.0019
#  dtype: float64)

# %%
model1.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                 Profit   R-squared:                       0.820
# Model:                            OLS   Adj. R-squared:                  0.809
# Method:                 Least Squares   F-statistic:                     70.05
# Date:                Mon, 26 Sep 2022   Prob (F-statistic):           3.53e-17
# Time:                        00:28:32   Log-Likelihood:                 46.632
# No. Observations:                  50   AIC:                            -85.26
# Df Residuals:                      46   BIC:                            -77.62
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.1366      0.048      2.870      0.006       0.041       0.232
# ...

# %% [markdown]
# # Model Validation :-

# %% [markdown]
# # Collinearty check

# %%
rsq_r = smf.ols('RD_S~ Admin+Mark_S', data=df2).fit().rsquared
vif_r = 1/(1-rsq_r)

rsq_a = smf.ols('Admin ~ RD_S+Mark_S', data=df2).fit().rsquared
vif_a = 1/(1-rsq_a)

rsq_m = smf.ols('Mark_S~ RD_S+Admin', data=df2).fit().rsquared
vif_m = 1/(1-rsq_m)

d1 = {'Varriables':['RD_S','Admin','Mark_S'], 'Vif':[vif_r,vif_a,vif_m]}
vif_df= pd.DataFrame(d1)
vif_df
# Out:
#   Varriables       Vif
# 0       RD_S  2.197366
# 1      Admin  1.200124
# 2     Mark_S  2.042598

# %% [markdown]
# #All the variables have vif < 20, therfore no multicollinearty in variables. So we will consider all the variables in model building

# %% [markdown]
# # 2. Residual Analysis
# Q-Q plot

# %%
# Test for Normality of Residuals (Q-Q Plot) using residual model (model.resid)
import statsmodels.api as sm
sm.qqplot(model1.resid,line='q')
plt.title("Normal Q-Q plot of residuals")
plt.show()

# %%
list(np.where(model1.resid < -0.10))
# Out:
# [array([27, 46, 47, 49], dtype=int64)]

# %%
#Residual plot for Homoscedasticity

# %%
def get_standardized_values( vals ):
    return (vals - vals.mean())/vals.std()  # z = (x-mu)/sigma

# %%
plt.scatter(get_standardized_values(model1.fittedvalues),
            get_standardized_values(model1.resid))

plt.title('Residual Plot')
plt.xlabel('standarized fitted values')
plt.ylabel('standarized residual values')
plt.show()

# %%
#Test of errors (Residual Vs Regressor)
#Test for errors or Residuals Vs Regressors or independent variables or predictors

#using Residual Regression Plots code graphics.plot_regress_exog(model,'x',fig)

#exog = x-variable & endog = y-variable

# %%
fig = plt.figure(figsize=(15,8))
sm.graphics.plot_regress_exog(model1,'RD_S', fig=fig )
plt.show()
# Out:
# eval_env: 1

# %%
fig = plt.figure(figsize=(15,8))
sm.graphics.plot_regress_exog(model1,'Admin', fig=fig )
plt.show()
# Out:
# eval_env: 1

# %%
fig = plt.figure(figsize=(15,8))
sm.graphics.plot_regress_exog(model1,'Mark_S', fig=fig )
plt.show()
# Out:
# eval_env: 1

# %% [markdown]
# # Model Deletion Diagnostics

# %%
#Detecting Influencers/Outliers

# %%
(c, _)= model1.get_influence().cooks_distance
c
# Out:
# array([7.97427386e-04, 1.67644017e-04, 1.77660360e-02, 9.69460121e-03,
#        8.69201307e-05, 1.05182213e-03, 4.46065697e-02, 2.35765100e-04,
#        1.30826858e-04, 7.71762576e-08, 1.06818576e-02, 1.34233740e-02,
#        4.51295012e-03, 1.61699568e-03, 8.63211622e-03, 3.75010343e-03,
#        1.92948032e-03, 1.35455634e-03, 6.41005901e-04, 2.89158137e-02,
#        6.50310923e-05, 1.21838331e-02, 3.44462595e-03, 1.63365058e-03,
#        1.52859209e-03, 3.29551640e-03, 1.48053832e-04, 3.20267301e-02,
#        3.78340343e-03, 1.82704651e-03, 5.17150514e-03, 3.01900936e-03,
#        9.21586065e-03, 2.27884241e-05, 6.86436259e-04, 2.23010896e-03,
#        7.12078239e-03, 2.24628401e-03, 1.28633599e-02, 6.34762457e-05,
#        3.95965402e-05, 7.54159279e-04, 4.95725792e-05, 1.52183368e-02,
#        2.94808923e-03, 5.02143271e-02, 1.82778923e-01, 2.17484344e-01,
#        2.65123452e-02, 7.59720312e-01])

# %%
#Plot the influencer values using stem plot
fig = plt.subplots(figsize=(20, 7))
plt.stem(np.arange(len(df2)), np.round(c,3))
plt.xlabel('Row index')
plt.ylabel('Cooks distance')
plt.show()

# %%
np.argmax(c), np.max(c)
# Out:
# (49, 0.759720312420429)

# %%
fig,ax = plt.subplots(figsize=(15, 15))
influence_plot(model1, ax=ax)
plt.show()

# %%
k = df2.shape[1] # K is no. of columns

n = df2.shape[0] # n is no. of rows
print('no. of columns=',k,"\n",'no. of rows=', n)

# leverage cutoff value
leverage_cutoff = 3*((k + 1)/n)
print('leverage cutoff =',leverage_cutoff)
# Out:
# no. of columns= 4
#  no. of rows= 50
# leverage cutoff = 0.30000000000000004

# %%
df2[df2.index.isin([49])]
# Out:
#        RD_S     Admin    Mark_S  Profit
# 49  0.46267  0.500148  0.092085     0.0

# %%
# Significant differences in value of RD_S & Profit in 49th record
df2
# Out:
#         RD_S     Admin    Mark_S    Profit
# 0   1.000000  0.651744  1.000000  1.000000
# 1   0.983305  0.761972  0.940654  0.997355
# 2   0.927748  0.379579  0.864115  0.993178
# 3   0.872719  0.512998  0.811474  0.947292
# 4   0.858975  0.305328  0.775228  0.853171
# 5   0.796900  0.369448  0.768190  0.801382
# 6   0.813517  0.730161  0.267755  0.796490
# 7   0.787321  0.717457  0.685223  0.794407
# 8   0.728127  0.741733  0.659124  0.774468
# 9   0.745070  0.436929  0.645011  0.760661
# 10  0.615089  0.451506  0.483649  0.740175
# 11  0.607558  0.308364  0.527455  0.729686
# 12  0.566248  0.578836  0.527657  0.714629
# 13  0.554893  0.641066  0.533670  0.673644
# 14  0.724490  0.801327  0.541859  0.664044
# 15  0.691606  0.543030  0.553061  0.648921
# 16  0.470071  0.535270  0.558530  0.632454
# 17  0.571062  0.714013  0.597323  0.623317
# 18  0.553417  0.478772  0.623597  0.617103
# 19  0.521080  0.778236  0.159380  0.608713
# 20  0.459396  0.476424  0.631566  0.584482
# ...

# %%
df2.shape
# Out:
# (50, 4)

# %%
# Significant difference in value of 49th record, so it is a outlier, droping it
df2_new = df2
df2_new = df2_new.drop(df2_new.index[[49]],axis=0)

# %%
df2_new.shape
# Out:
# (49, 4)

# %%
df2_new
# Out:
#         RD_S     Admin    Mark_S    Profit
# 0   1.000000  0.651744  1.000000  1.000000
# 1   0.983305  0.761972  0.940654  0.997355
# 2   0.927748  0.379579  0.864115  0.993178
# 3   0.872719  0.512998  0.811474  0.947292
# 4   0.858975  0.305328  0.775228  0.853171
# 5   0.796900  0.369448  0.768190  0.801382
# 6   0.813517  0.730161  0.267755  0.796490
# 7   0.787321  0.717457  0.685223  0.794407
# 8   0.728127  0.741733  0.659124  0.774468
# 9   0.745070  0.436929  0.645011  0.760661
# 10  0.615089  0.451506  0.483649  0.740175
# 11  0.607558  0.308364  0.527455  0.729686
# 12  0.566248  0.578836  0.527657  0.714629
# 13  0.554893  0.641066  0.533670  0.673644
# 14  0.724490  0.801327  0.541859  0.664044
# 15  0.691606  0.543030  0.553061  0.648921
# 16  0.470071  0.535270  0.558530  0.632454
# 17  0.571062  0.714013  0.597323  0.623317
# 18  0.553417  0.478772  0.623597  0.617103
# 19  0.521080  0.778236  0.159380  0.608713
# 20  0.459396  0.476424  0.631566  0.584482
# ...

# %% [markdown]
# # Improving model

# %%
model2 = smf.ols('Profit ~RD_S+Admin+Mark_S', data= df2_new).fit()

# %%
model2.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                 Profit   R-squared:                       0.898
# Model:                            OLS   Adj. R-squared:                  0.891
# Method:                 Least Squares   F-statistic:                     132.4
# Date:                Mon, 26 Sep 2022   Prob (F-statistic):           2.43e-22
# Time:                        01:01:38   Log-Likelihood:                 62.287
# No. Observations:                  49   AIC:                            -116.6
# Df Residuals:                      45   BIC:                            -109.0
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.1875      0.035      5.390      0.000       0.117       0.258
# ...

# %%
(c1, _)= model2.get_influence().cooks_distance
c1
# Out:
# array([1.22062080e-04, 4.15838992e-03, 2.86938062e-02, 1.77363982e-02,
#        2.91126120e-03, 3.80556392e-03, 1.14657327e-02, 6.07023632e-04,
#        3.45088206e-04, 8.12084912e-04, 1.27853131e-02, 1.41871961e-02,
#        7.34064187e-03, 2.72218275e-03, 2.28916866e-02, 1.29854718e-02,
#        4.21577524e-03, 1.70949052e-03, 1.16372006e-03, 1.97739373e-02,
#        1.93387084e-05, 1.04117240e-02, 3.19053672e-03, 1.03681419e-03,
#        3.94846780e-04, 3.04795764e-03, 4.57795163e-04, 3.11992098e-02,
#        3.10124094e-03, 2.75545470e-04, 1.28899301e-03, 6.71700230e-04,
#        1.07986788e-03, 1.68863845e-04, 6.91150537e-03, 2.66542939e-03,
#        2.24375899e-02, 9.49295573e-07, 2.04717759e-02, 1.34038772e-03,
#        2.38478057e-04, 3.84085789e-04, 1.87917996e-05, 1.54495813e-02,
#        5.21550556e-04, 6.39813141e-02, 1.38785822e-01, 6.29718963e-01,
#        1.18380664e-01])

# %%
#Plot the influencers values using stem plot
fig = plt.subplots(figsize=(20, 7))
plt.stem(np.arange(len(df2_new)), np.round(c1,3))
plt.xlabel('Row index')
plt.ylabel('Cooks distance')
plt.show()

# %%
np.argmax(c1), np.max(c1)
# Out:
# (47, 0.6297189627276298)

# %%
# leverage cutoff value
leverage_cutoff = 3*((4 + 1)/49)
print('leverage cutoff =',leverage_cutoff)
# Out:
# leverage cutoff = 0.30612244897959184

# %%
# deleting 47th record since its cook's distance value is beyond leverage cutoff
df2_new[df2_new.index.isin([47])]
# Out:
#        RD_S     Admin   Mark_S   Profit
# 47  0.46267  0.640547  0.15938  0.15699

# %%
df2_new = df2_new.drop(df2_new.index[[47]],axis=0)

# %%
df2_new.shape
# Out:
# (48, 4)

# %% [markdown]
# # Rebuilding Model

# %%
#Rebuild model and generate R-Squared and AIC values

model3= smf.ols('Profit ~ RD_S+ Admin+ Mark_S', data= df2_new).fit()

# %%
model3.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                 Profit   R-squared:                       0.958
# Model:                            OLS   Adj. R-squared:                  0.955
# Method:                 Least Squares   F-statistic:                     337.1
# Date:                Mon, 26 Sep 2022   Prob (F-statistic):           2.32e-30
# Time:                        01:15:20   Log-Likelihood:                 83.796
# No. Observations:                  48   AIC:                            -159.6
# Df Residuals:                      44   BIC:                            -152.1
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.2108      0.022      9.655      0.000       0.167       0.255
# ...

# %%
(c2, _)= model3.get_influence().cooks_distance
c2
# Out:
# array([3.35226658e-03, 1.58305486e-02, 7.41097611e-02, 4.43710264e-02,
#        1.07183216e-02, 1.05167142e-02, 4.88283271e-03, 3.32800475e-03,
#        2.38243637e-04, 4.82495714e-03, 2.21962814e-02, 2.50169182e-02,
#        1.55329269e-02, 5.09618495e-03, 8.39727982e-02, 4.64922376e-02,
#        1.06714162e-02, 5.11411076e-03, 2.94090509e-03, 7.59478105e-03,
#        4.37915015e-04, 1.96526563e-02, 5.03990084e-03, 6.61653744e-04,
#        1.13981265e-02, 2.39540568e-03, 8.83179862e-03, 4.78769887e-02,
#        8.74423316e-05, 2.11602496e-03, 3.90325858e-04, 1.70017356e-03,
#        6.11173996e-03, 6.83085625e-04, 1.90560580e-02, 6.16442881e-03,
#        6.50775687e-02, 3.37281516e-04, 5.82259650e-02, 5.30221528e-03,
#        4.97812478e-04, 4.90712139e-04, 3.63487410e-04, 1.73087423e-02,
#        3.98387654e-03, 1.04891271e-01, 1.45554305e-01, 3.80132321e-01])

# %%
#Plot the influencers values using stem plot
fig = plt.subplots(figsize=(20, 7))
plt.stem(np.arange(len(df2_new)), np.round(c2,3))
plt.xlabel('Row index')
plt.ylabel('Cooks distance')
plt.show()

# %%
np.argmax(c2), np.max(c2)
# Out:
# (47, 0.38013232073442627)

# %%
# leverage cutoff value
leverage_cutoff = 3*((4 + 1)/49)
print('leverage cutoff =',leverage_cutoff)
# Out:
# leverage cutoff = 0.30612244897959184

# %%
# deleting 46th record since its cook's distance value is beyond leverage cutoff
df2_new[df2_new.index.isin([46])]
# Out:
#         RD_S    Admin    Mark_S   Profit
# 46  0.004693  0.49126  0.628268  0.19602

# %%
df3_new = df2_new.drop(df2_new.index[[46]],axis=0)

# %%
df3_new.shape
# Out:
# (46, 4)

# %%
#Rebuild model and generate R-Squared and AIC values

model4= smf.ols('Profit ~ RD_S+ Admin+ Mark_S', data= df3_new).fit()

# %%
model4.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                 Profit   R-squared:                       0.959
# Model:                            OLS   Adj. R-squared:                  0.956
# Method:                 Least Squares   F-statistic:                     329.4
# Date:                Mon, 26 Sep 2022   Prob (F-statistic):           3.38e-29
# Time:                        01:28:45   Log-Likelihood:                 84.210
# No. Observations:                  46   AIC:                            -160.4
# Df Residuals:                      42   BIC:                            -153.1
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.2342      0.022     10.552      0.000       0.189       0.279
# ...

# %% [markdown]
# # Table containing R^2 value for each prepared model

# %%
d2={'Model Name':['Model1','Model2','Model3','Model4'],'Rsquared':[model1.rsquared,model2.rsquared,model3.rsquared,model4.rsquared]}
table=pd.DataFrame(d2)
table
# Out:
#   Model Name  Rsquared
# 0     Model1  0.820417
# 1     Model2  0.898217
# 2     Model3  0.958302
# 3     Model4  0.959233

# %%
#Inference : model4 is having highest R-squared value

# %% [markdown]
# # Model Predictions

# %%
# let the data for prediction is
pred_data=pd.DataFrame({'RD_S':60000,"Admin":100000,"Mark_S":130000},index=[0])

# %%
pred_data
# Out:
#     RD_S   Admin  Mark_S
# 0  60000  100000  130000

# %%
# Manual Prediction of Price
model4.predict(pred_data)
# Out:
# 0    47661.878538
# dtype: float64

# %%
# Manual Prediction of Price
model3.predict(pred_data)
# Out:
# 0    49964.344511
# dtype: float64
